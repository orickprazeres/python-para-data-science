# %% [markdown]
# # Relatorio de Analise IV

# %%
## selecao e frequencia

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep=';')
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22802  Apartamento                 Méier        2      0       0    70
# 22803    Quitinete                Centro        0      0       0    27
# 22804  Apartamento           Jacarepaguá        3      1       2    78
# 22805  Apartamento  São Francisco Xavier        2      1       0    48
# 22806  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# 2       800.0       390.0  20.0
# 3       800.0       230.0   NaN
# 4      1200.0         NaN   NaN
# ...       ...         ...   ...
# 22802   900.0       490.0  48.0
# 22803   800.0       350.0  25.0
# 22804  1800.0       800.0  40.0
# 22805  1400.0       509.0  37.0
# 22806  3000.0       760.0   NaN
#
# [22807 rows x 9 columns]

# %%
## Selecione somente os imóveis classificados com tipo 'Apartamento'.
selecao = dados.Tipo == 'Apartamento'
n1 = dados[selecao]
n1
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# 5      Apartamento              Cachambi        2      0       0    50
# 8      Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 22800  Apartamento        Vila Valqueire        2      0       0    52
# 22802  Apartamento                 Méier        2      0       0    70
# 22804  Apartamento           Jacarepaguá        3      1       2    78
# 22805  Apartamento  São Francisco Xavier        2      1       0    48
# 22806  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 2       800.0       390.0  20.0
# 3       800.0       230.0   NaN
# 4      1200.0         NaN   NaN
# 5      1300.0       301.0  17.0
# 8      1200.0         NaN   NaN
# ...       ...         ...   ...
# 22800  1000.0       550.0   NaN
# 22802   900.0       490.0  48.0
# 22804  1800.0       800.0  40.0
# 22805  1400.0       509.0  37.0
# 22806  3000.0       760.0   NaN
#
# [19532 rows x 9 columns]

# %%
## Selecione os imóveis classificados com tipos 'Casa', 'Casa de Condomínio' e 'Casa de Vila'.

selecao = (dados.Tipo == 'Casa') | (dados.Tipo == 'Casa de Condomínio') | (dados.Tipo == 'Casa de Vila')
n2 = dados[selecao]
n2
# Out:
#                      Tipo                   Bairro  Quartos  Vagas  Suites  \
# 1                    Casa          Jardim Botânico        2      0       1
# 6      Casa de Condomínio          Barra da Tijuca        5      4       5
# 7      Casa de Condomínio                    Ramos        2      2       0
# 15     Casa de Condomínio                  Taquara        3      1       1
# 19     Casa de Condomínio          Barra da Tijuca        4      3       2
# ...                   ...                      ...      ...    ...     ...
# 22772  Casa de Condomínio  Freguesia (Jacarepaguá)        3      3       1
# 22774                Casa            Bento Ribeiro        2      1       0
# 22782  Casa de Condomínio          Barra da Tijuca        3      5       3
# 22785                Casa                   Centro        5      0       1
# 22801  Casa de Condomínio          Barra da Tijuca        5      3       4
#
#        Area    Valor  Condominio    IPTU
# 1       100   7000.0         NaN     NaN
# 6       750  22000.0         NaN     NaN
# 7        65   1000.0         NaN     NaN
# 15      115   2000.0         NaN     NaN
# 19      466   7500.0      2695.0     NaN
# ...     ...      ...         ...     ...
# 22772   155   2000.0       530.0  1250.0
# 22774    60   1400.0         NaN     NaN
# 22782  1000  20000.0      3000.0     NaN
# 22785   160   5000.0         NaN    80.0
# 22801   450  15000.0      1711.0  2332.0
#
# [1963 rows x 9 columns]

# %%
## Selecione os imóveis com área entre 60 e 100 metros quadrados, incluindo os limites.

selecao = (dados.Area >= 60) & (dados.Area <= 100)
n3 = dados[selecao]
n3
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 1                    Casa           Jardim Botânico        2      0       1
# 4             Apartamento              Vista Alegre        3      1       0
# 7      Casa de Condomínio                     Ramos        2      2       0
# 9             Apartamento                    Grajaú        2      1       0
# 10            Apartamento       Lins de Vasconcelos        3      1       1
# ...                   ...                       ...      ...    ...     ...
# 22795         Apartamento  Recreio dos Bandeirantes        3      2       1
# 22797         Apartamento                    Leblon        3      0       1
# 22802         Apartamento                     Méier        2      0       0
# 22804         Apartamento               Jacarepaguá        3      1       2
# 22806         Apartamento                    Leblon        2      0       0
#
#        Area   Valor  Condominio   IPTU
# 1       100  7000.0         NaN    NaN
# 4        70  1200.0         NaN    NaN
# 7        65  1000.0         NaN    NaN
# 9        70  1500.0       642.0   74.0
# 10       90  1500.0       455.0   14.0
# ...     ...     ...         ...    ...
# 22795    88  1550.0       790.0    NaN
# 22797    80  3000.0      1010.0  249.0
# 22802    70   900.0       490.0   48.0
# 22804    78  1800.0       800.0   40.0
# 22806    70  3000.0       760.0    NaN
#
# [8882 rows x 9 columns]

# %%
## Selecione os imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00.

selecao = (dados.Quartos == 4) & (dados.Valor <=2000)
n4 = dados[selecao]
n4
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 486           Apartamento  Recreio dos Bandeirantes        4      2       2
# 1009          Apartamento                   Taquara        4      1       1
# 1633          Apartamento                    Tijuca        4      1       0
# 1981                 Casa              Campo Grande        4      1       4
# 2071          Apartamento                    Tijuca        4      1       2
# 2123                 Casa         Engenho de Dentro        4      3       0
# 2221          Apartamento  Recreio dos Bandeirantes        4      2       2
# 2409          Apartamento  Recreio dos Bandeirantes        4      4       1
# 3583          Apartamento           Barra da Tijuca        4      2       2
# 3990                 Casa              Campo Grande        4      1       0
# 3583    114  2000.0      1174.0   130.0
# 3990    140  1700.0         NaN     NaN
# 3991    115  1900.0       500.0     NaN
# 4285    100  2000.0         NaN     2.0
# 4395    105  1900.0      1492.0   205.0
# 4493    120  2000.0       633.0     NaN
# 5143    110  1300.0         NaN     NaN
# 5558    153  2000.0      1414.0   352.0
# 5613    188  2000.0      2000.0   309.0
# 6598    178  1900.0      1100.0   270.0
# 6877    100  1800.0         NaN    40.0
# 6888    125  1900.0         NaN     NaN
# 7709    280  1800.0      1400.0   580.0
# 7736    250  1500.0      1380.0   700.0
# 7957    160  1900.0      1093.0   183.0
# 10229   160  1900.0      1038.0   158.0
# 11052   110  1750.0       550.0   993.0
# 11207   188  2000.0      2000.0   309.0
# 11620   180  2000.0      1924.0   423.0
# 12118   185  1800.0      2000.0   270.0
# 12389   188  2000.0      2000.0  3090.0
# 12671   160  1900.0       930.0   150.0
# 13462    96  1350.0       747.0     NaN
# 13685   153  2000.0      1534.0   387.0
# 13813   148  1600.0      1766.0     NaN
# 13971   162  2000.0      1400.0   380.0
# 14186   128  1600.0         NaN   228.0
# 15142   120  1800.0       195.0    30.0
# 15165   100  1300.0         NaN     NaN
# 15695   188  2000.0      2000.0   380.0
# 16078   160  1900.0       880.0     NaN
# 16199   160  1900.0       912.0   160.0
# 16306   110  1650.0       500.0     NaN
# 16973   120  1700.0         NaN     NaN
# 17345   155  2000.0       800.0   237.0
# 17950   190  1200.0         NaN     NaN
# 18071   366  1890.0         NaN   208.0
# 18327   159  1800.0         NaN     NaN
# 18462    99  1800.0         NaN     NaN
# 18645   100  1600.0         NaN     NaN
# 18864    63  2000.0       416.0     NaN
# 19597   180  1850.0       300.0     NaN
# 20380    80  1600.0       950.0     NaN
# 21139   140  2000.0       600.0     NaN
# 21185   148  1500.0      1600.0   196.0
# 21691   180  1900.0         NaN   176.0
# 22003   160  1900.0      1038.0     NaN
# 22157   120  1600.0         NaN     NaN

# %%
print("Nº de imóveis classificados com tipo 'Apartamento' -> {}".format(n1.shape[0]))
print("Nº de imóveis classificados com tipos 'Casa', 'Casa de Condomínio' e 'Casa de Vila' -> {}".format(n2.shape[0]))
print("Nº de imóveis com área entre 60 e 100 metros quadrados, incluindo os limites -> {}".format(n3.shape[0]))
print("Nº de imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00 -> {}".format(n4.shape[0]))
# Out:
# Nº de imóveis classificados com tipo 'Apartamento' -> 19532
# Nº de imóveis classificados com tipos 'Casa', 'Casa de Condomínio' e 'Casa de Vila' -> 1963
# Nº de imóveis com área entre 60 e 100 metros quadrados, incluindo os limites -> 8882
# Nº de imóveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2.000,00 -> 56

# %%
n1.shape[0]
# Out:
# 19532
